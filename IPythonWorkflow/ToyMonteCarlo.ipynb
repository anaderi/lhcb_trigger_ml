# %%
from sklearn.neighbors import NearestNeighbors
import random
import pandas
import math
from mpl_toolkits.mplot3d import Axes3D

import toymc
# Out:
# getRandom is ok
# toyMC is ok

# %% [markdown]
# #Tests with real monte-carlo

# %%
def CovariationMatrixVisualComparison(originalCovariation, toyCovariation):
    fig = plt.figure(figsize = (12, 5))
    assert originalCovariation.shape == toyCovariation.shape, "different size of matrices"
    vars1, vars2 = originalCovariation.shape
    x, y = range(vars1), range(vars2)
    X, Y = meshgrid(x,y)
    X = X.flatten() 
    Y = Y.flatten() 
    Zmin = zeros_like(X)
    ZmaxLeft  = originalCovariation.flatten()
    ZmaxRight = toyCovariation.flatten()
    
    maximalCov = max(numpy.max(toyCovariation), numpy.max(originalCovariation))

    ax = fig.add_subplot(121, projection='3d')
    ax.bar3d(X - 0.5, Y - 0.5, Zmin, 1, 1, ZmaxLeft,  color='b', zsort='average')
    ax.set_zlim(0, maximalCov)
    ax.set_title("Original MC")
    ax.view_init(35, 225 + 30)

    bx = fig.add_subplot(122, projection='3d')
    bx.bar3d(X - 0.5, Y - 0.5, Zmin, 1, 1, ZmaxRight, color='b', zsort='average')
    bx.set_zlim(0, maximalCov)
    bx.set_title("Toy MC")
    bx.view_init(35, 225 + 30)
    plt.show()

# %%
def TestOnFile(fileName, excludedFeatures = None, clusterizationFeatures = None, integerFeatures = None):
    """
    Excluded features - features we absolutely don't take into account
    ClusterizationFeatures - very close to integer ones, usually have some bool or integer values,
        but events with different values in these columns should not be mixed together
        example: 'isSignal', number of muons
    IntegerFeatures - (rarely used) features that have some discrete values, but events can be mixed together
        if they have different values in these columns, the result will be integer
        example: some weight of event, which should be integer due to technical restrictions
    """
    df = pandas.read_csv(fileName, sep="\t")

    selectedColumns = [col for col in df.columns if col not in excludedFeatures] 
    if excludedFeatures is None:
        excludedFeatures = []
    else:
        print "\nEXCLUDED columns:\n", excludedFeatures

    print "\nSTAYED columns:\n", selectedColumns

    if integerFeatures is None:
        integerFeatures = []
    else:
        print "\nINTEGER columns:\n", integerFeatures
        
    if clusterizationFeatures is None:
        clusterizationFeatures = []
    else: 
        print "\nCLUSTERIZATION columns:\n", clusterizationFeatures
        
    originalMC = df[selectedColumns]
    toyMC = toymc.generateToyMonteCarloWithSpecialFeatures(originalMC, len(originalMC), \
                                clusterization_features=clusterizationFeatures, integer_features=integerFeatures)

    numpy.set_printoptions(precision=4, suppress = True)
    for column in originalMC.columns:
        print column, 'histogram :'
        hist([originalMC[column], toyMC[column]], histtype = 'step', bins=20)
        pylab.show()

    print "\nMEANS"
    means1 = []
    means2 = []
    for column in originalMC.columns:
        mean1 = numpy.mean(originalMC[column])
        mean2 = numpy.mean(toyMC[column])
        means1.append(mean1)
        means2.append(mean2)
    df = pandas.DataFrame()
    df['column']   = originalMC.columns
    df['original'] = means1
    df['toy']      = means2
    df['difference'] = numpy.array(means1) - means2
    df['ratio']    = abs(df['difference']) / abs(df['original'])
    df.set_index('column')
    print df 
    
    toyCovar  = numpy.cov(toyMC.T)[:6,:6]
    origCovar = numpy.cov(originalMC.T)[:6,:6]
    
    CovariationMatrixVisualComparison(origCovar, toyCovar)

    print "Original MC covar (first 6 vars):\n", origCovar
    print "ToyMC covar (first 6 vars):\n", toyCovar
    
    col = 0
    for firstColumn in originalMC.columns[:4]:
        col += 1
        for secondColumn in originalMC.columns[col:4]:
            xmin = numpy.min(originalMC[firstColumn])
            xmax = numpy.max(originalMC[firstColumn])
            ymin = numpy.min(originalMC[secondColumn])
            ymax = numpy.max(originalMC[secondColumn])
            
            fig = plt.figure(figsize = (12, 5))
            ax = fig.add_subplot(121)
            ax.plot(originalMC[firstColumn], originalMC[secondColumn], '.', alpha=0.1)
            ax.set_xlim(xmin, xmax)
            ax.set_ylim(ymin, ymax)
            ax.set_title("original MC")
            
            bx = fig.add_subplot(122)
            bx.plot(toyMC[firstColumn], toyMC[secondColumn], '.', alpha=0.1)
            bx.set_xlim(xmin, xmax)
            bx.set_ylim(ymin, ymax)
            bx.set_title("toy MC")
            fig.suptitle(firstColumn + " vs " + secondColumn)
            
            pylab.show()

# %%
fileNames = ["/Users/axelr/Downloads/A_folds_0_nfolds_2.csv", "/Users/axelr/Downloads/B_folds_1_nfolds_2.csv"]

TestOnFile(fileNames[0], excludedFeatures=["MN_weight"], \
           clusterizationFeatures=["isolationd", "isolatione", "isolationf", "is_signal"])
# Out:
# EXCLUDED columns:
# ['MN_weight']
#
# STAYED columns:
# ['FlightD_FlightDE', 'LifeTime_N', 'dira_N', 'min_p_IPSig', 'FlightDistance', 'FlightDistanceError', 'IPSig', 'VertexChi2', 'pt', 'DOCAone', 'DOCAtwo', 'DOCAthree', 'isolationd', 'isolatione', 'isolationf', 'CDF3', 'p0_track_MatchChi2', 'p1_track_MatchChi2', 'p2_track_MatchChi2', 'Laura_SumBDT', 'min_p_IP', 'min_p_pt', 'min_track', 'min_DOCA', 'p0_Laura_IsoBDT', 'p1_Laura_IsoBDT', 'p2_Laura_IsoBDT', 'p0_IP', 'p0_IPSig', 'p0_pt', 'p1_IP', 'p1_IPSig', 'p1_pt', 'p2_IP', 'p2_IPSig', 'p2_pt', 'is_signal']
#
# CLUSTERIZATION columns:
# ['isolationd', 'isolatione', 'isolationf', 'is_signal']
# Generating ...
# Copied 183 events in 149 groups from original file. Totally generated 23143 rows
# FlightD_FlightDE histogram :
# LifeTime_N histogram :
# dira_N histogram :
# min_p_IPSig histogram :
# FlightDistance histogram :
# FlightDistanceError histogram :
# IPSig histogram :
# VertexChi2 histogram :
# pt histogram :
# DOCAone histogram :
# DOCAtwo histogram :
# DOCAthree histogram :
# isolationd histogram :
# isolatione histogram :
# isolationf histogram :
# CDF3 histogram :
# p0_track_MatchChi2 histogram :
# p1_track_MatchChi2 histogram :
# p2_track_MatchChi2 histogram :
# Laura_SumBDT histogram :
# min_p_IP histogram :
# min_p_pt histogram :
# min_track histogram :
# min_DOCA histogram :
# p0_Laura_IsoBDT histogram :
# p1_Laura_IsoBDT histogram :
# p2_Laura_IsoBDT histogram :
# p0_IP histogram :
# p0_IPSig histogram :
# p0_pt histogram :
# p1_IP histogram :
# p1_IPSig histogram :
# p1_pt histogram :
# p2_IP histogram :
# p2_IPSig histogram :
# p2_pt histogram :
# is_signal histogram :
# MEANS
#                  column     original          toy  difference     ratio
# 0      FlightD_FlightDE    34.904791    34.626746    0.278044  0.007966
# 1            LifeTime_N     0.333474     0.333340    0.000134  0.000402
# 2                dira_N     0.010132     0.010198   -0.000066  0.006495
# 3           min_p_IPSig     8.250877     8.281380   -0.030503  0.003697
# 4        FlightDistance    14.535186    14.543941   -0.008755  0.000602
# 5   FlightDistanceError     0.475160     0.476811   -0.001651  0.003475
# 6                 IPSig     5.080409     5.083206   -0.002797  0.000551
# 7            VertexChi2     4.742510     4.765966   -0.023456  0.004946
# 8                    pt  4588.498192  4571.588054   16.910138  0.003685
# 9               DOCAone     0.045204     0.045344   -0.000139  0.003083
# 10              DOCAtwo     0.037711     0.037684    0.000027  0.000715
# 11            DOCAthree     0.050060     0.050156   -0.000096  0.001912
# 12           isolationd     0.321739     0.321739    0.000000  0.000000
# 13           isolatione     0.318412     0.318412    0.000000  0.000000
# 14           isolationf     0.312578     0.312578    0.000000  0.000000
# 15                 CDF3     0.515084     0.516881   -0.001797  0.003489
# 16   p0_track_MatchChi2     6.740072     6.685309    0.054763  0.008125
# 17   p1_track_MatchChi2     5.878805     5.859966    0.018839  0.003205
# 18   p2_track_MatchChi2     5.911047     5.921197   -0.010149  0.001717
# 19         Laura_SumBDT    -0.781946    -0.783801    0.001855  0.002373
# 20             min_p_IP     0.229174     0.229531   -0.000357  0.001559
# 21             min_p_pt   784.145424   782.262712    1.882712  0.002401
# 22            min_track     0.856026     0.856805   -0.000779  0.000910
# 23             min_DOCA     0.016917     0.016954   -0.000037  0.002167
# 24      p0_Laura_IsoBDT    -0.267164    -0.267702    0.000538  0.002015
# 25      p1_Laura_IsoBDT    -0.253927    -0.254390    0.000463  0.001824
# 26      p2_Laura_IsoBDT    -0.260541    -0.261419    0.000877  0.003368
# 27                p0_IP     0.527754     0.521795    0.005959  0.011292
# 28             p0_IPSig    14.636228    14.543243    0.092985  0.006353
# 29                p0_pt   981.831780   979.227374    2.604406  0.002653
# 30                p1_IP     0.354994     0.354796    0.000198  0.000557
# 31             p1_IPSig    15.392643    15.447301   -0.054659  0.003551
# 32                p1_pt  2235.610067  2226.703107    8.906960  0.003984
# 33                p2_IP     0.443718     0.440782    0.002936  0.006617
# 34             p2_IPSig    15.289291    15.167472    0.121819  0.007968
# 35                p2_pt  1645.395615  1640.927047    4.468568  0.002716
# 36            is_signal     0.792162     0.792162    0.000000  0.000000
#
# [37 rows x 5 columns]
# Original MC covar (first 6 vars):
# [[ 767.7774   -3.0421   -0.0689  107.4248  194.0224   -2.0503]
#  [  -3.0421    0.0304    0.0004   -0.5011   -1.2708   -0.0033]
#  [  -0.0689    0.0004    0.0002   -0.0107   -0.0543   -0.0012]
#  [ 107.4248   -0.5011   -0.0107   31.2016   28.0329   -0.3085]
#  [ 194.0224   -1.2708   -0.0543   28.0329  190.9508    3.1284]
#  [  -2.0503   -0.0033   -0.0012   -0.3085    3.1284    0.1562]]
# ToyMC covar (first 6 vars):
# [[ 604.4558   -2.3669   -0.0635   88.062   158.4929   -1.5532]
#  [  -2.3669    0.025     0.0003   -0.3993   -1.0148   -0.0032]
#  [  -0.0635    0.0003    0.0002   -0.0103   -0.049    -0.001 ]
#  [  88.062    -0.3993   -0.0103   25.6467   23.6627   -0.2424]
#  [ 158.4929   -1.0148   -0.049    23.6627  157.2155    2.58  ]
#  [  -1.5532   -0.0032   -0.001    -0.2424    2.58      0.1267]]

# %%
TestOnFile(fileNames[1], excludedFeatures=["isolationd", "isolatione", "isolationf", "is_signal", "MN_weight"])
# Out:
# EXCLUDED columns:
# ['isolationd', 'isolatione', 'isolationf', 'is_signal', 'MN_weight']
#
# STAYED columns:
# ['FlightD_FlightDE', 'LifeTime_N', 'dira_N', 'min_p_IPSig', 'FlightDistance', 'FlightDistanceError', 'IPSig', 'VertexChi2', 'pt', 'DOCAone', 'DOCAtwo', 'DOCAthree', 'CDF3', 'p0_track_MatchChi2', 'p1_track_MatchChi2', 'p2_track_MatchChi2', 'Laura_SumBDT', 'min_p_IP', 'min_p_pt', 'min_track', 'min_DOCA', 'p0_Laura_IsoBDT', 'p1_Laura_IsoBDT', 'p2_Laura_IsoBDT', 'p0_IP', 'p0_IPSig', 'p0_pt', 'p1_IP', 'p1_IPSig', 'p1_pt', 'p2_IP', 'p2_IPSig', 'p2_pt']
# FlightD_FlightDE
#  histogram :
# LifeTime_N histogram :
# dira_N histogram :
# min_p_IPSig histogram :
# FlightDistance histogram :
# FlightDistanceError histogram :
# IPSig histogram :
# VertexChi2 histogram :
# pt histogram :
# DOCAone histogram :
# DOCAtwo histogram :
# DOCAthree histogram :
# CDF3 histogram :
# p0_track_MatchChi2 histogram :
# p1_track_MatchChi2 histogram :
# p2_track_MatchChi2 histogram :
# Laura_SumBDT histogram :
# min_p_IP histogram :
# min_p_pt histogram :
# min_track histogram :
# min_DOCA histogram :
# p0_Laura_IsoBDT histogram :
# p1_Laura_IsoBDT histogram :
# p2_Laura_IsoBDT histogram :
# p0_IP histogram :
# p0_IPSig histogram :
# p0_pt histogram :
# p1_IP histogram :
# p1_IPSig histogram :
# p1_pt histogram :
# p2_IP histogram :
# p2_IPSig histogram :
# p2_pt histogram :
# MEANS
#                  column     original          toy  difference     ratio
# 0      FlightD_FlightDE    34.658050    34.232812    0.425238  0.012270
# 1            LifeTime_N     0.332867     0.333327   -0.000460  0.001383
# 2                dira_N     0.010508     0.010355    0.000154  0.014632
# 3           min_p_IPSig     8.222825     8.217197    0.005628  0.000684
# 4        FlightDistance    14.528616    14.355078    0.173539  0.011945
# 5   FlightDistanceError     0.475758     0.475253    0.000505  0.001062
# 6                 IPSig     5.184013     5.145457    0.038555  0.007437
# 7            VertexChi2     4.701281     4.641864    0.059417  0.012639
# 8                    pt  4554.167957  4557.460715   -3.292758  0.000723
# 9               DOCAone     0.044904     0.044901    0.000003  0.000063
# 10              DOCAtwo     0.036982     0.036688    0.000294  0.007944
# 11            DOCAthree     0.049825     0.049459    0.000367  0.007359
# 12                 CDF3     0.510813     0.511345   -0.000532  0.001041
# 13   p0_track_MatchChi2     6.690348     6.699686   -0.009338  0.001396
# 14   p1_track_MatchChi2     5.867612     5.820388    0.047223  0.008048
# 15   p2_track_MatchChi2     5.951227     5.955736   -0.004509  0.000758
# 16         Laura_SumBDT    -0.784253    -0.787002    0.002749  0.003505
# 17             min_p_IP     0.229745     0.229220    0.000525  0.002285
# 18             min_p_pt   772.930785   772.218299    0.712486  0.000922
# 19            min_track     0.854497     0.854982   -0.000485  0.000567
# 20             min_DOCA     0.016920     0.016860    0.000060  0.003549
# 21      p0_Laura_IsoBDT    -0.267961    -0.269311    0.001350  0.005036
# 22      p1_Laura_IsoBDT    -0.255155    -0.256005    0.000849  0.003328
# 23      p2_Laura_IsoBDT    -0.259999    -0.260417    0.000418  0.001610
# 24                p0_IP     0.530061     0.523529    0.006532  0.012324
# 25             p0_IPSig    14.464063    14.290497    0.173566  0.012000
# 26                p0_pt   969.549902   968.726848    0.823054  0.000849
# 27                p1_IP     0.362323     0.360680    0.001643  0.004534
# 28             p1_IPSig    15.522169    15.464277    0.057892  0.003730
# 29                p1_pt  2218.462312  2226.602241   -8.139929  0.003669
# 30                p2_IP     0.441987     0.438853    0.003134  0.007090
# 31             p2_IPSig    15.207620    15.146107    0.061513  0.004045
# 32                p2_pt  1641.732256  1637.886033    3.846223  0.002343
#
# [33 rows x 5 columns]
# Original MC covar (first 6 vars):
# [[ 715.7892   -3.0175   -0.0668   99.5772  190.2555   -1.9603]
#  [  -3.0175    0.0305    0.0003   -0.4866   -1.2751   -0.0034]
#  [  -0.0668    0.0003    0.0002   -0.0108   -0.0563   -0.0012]
#  [  99.5772   -0.4866   -0.0108   30.1283   25.9748   -0.3095]
#  [ 190.2555   -1.2751   -0.0563   25.9748  194.398     3.2427]
#  [  -1.9603   -0.0034   -0.0012   -0.3095    3.2427    0.16  ]]
# ToyMC covar (first 6 vars):
# [[ 503.7169   -2.2387   -0.0551   74.5992  137.3249   -1.5279]
#  [  -2.2387    0.0242    0.0002   -0.3727   -0.9543   -0.0024]
#  [  -0.0551    0.0002    0.0001   -0.0093   -0.0432   -0.0009]
#  [  74.5992   -0.3727   -0.0093   23.1244   19.9956   -0.2431]
#  [ 137.3249   -0.9543   -0.0432   19.9956  144.7644    2.4915]
#  [  -1.5279   -0.0024   -0.0009   -0.2431    2.4915    0.1255]]

# %% [markdown]
# #Gauss distribution tests

# %%
def CompareResultWithToyMC(size, variables):
    rand = numpy.random.rand(variables, variables) * 2 - 1
    covar = rand + rand.T
    for i in range(variables):
        covar[i,i] = 1.0
    mean = numpy.random.randn(variables) * 2
    
    originalMC = numpy.random.multivariate_normal(mean, covar, size)
    originalMC = pandas.DataFrame(originalMC)
    toyMC, _ = toymc.generateToyMonteCarlo(originalMC, size)
    
    print "blue is original, green is toy MC"
    for column in originalMC.columns:
        hist([originalMC[column], toyMC[column]], histtype = 'step')
        pylab.title(column)
        pylab.show()
    numpy.set_printoptions(precision=5, suppress = True)
    print "mean:", list(numpy.mean(originalMC, axis = 0))
    print "mean:", list(numpy.mean(toyMC, axis = 0))
        
    print "covar (first 5 vars):\n", numpy.cov(originalMC.T)[:5,:5]
    print "covar (first 5 vars):\n", numpy.cov(toyMC.T)[:5,:5]
    for firstColumn in originalMC.columns[:3]:
        for secondColumn in originalMC.columns[:3]:
            if firstColumn == secondColumn:
                continue
            subplot(1,2,1)
            pylab.title("original MC")
            plot(originalMC[firstColumn], originalMC[secondColumn], '.', )
            pylab.xlim(-5, 5)
            pylab.ylim(-5, 5)
            subplot(1,2,2)
            pylab.title("toy MC")
            plot(toyMC[firstColumn], toyMC[secondColumn], '.')
            pylab.xlim(-5, 5)
            pylab.ylim(-5, 5)
            pylab.show()

CompareResultWithToyMC(3000, 10)
# Out:
# blue is original, green is toy MC
# mean: [2.8531206221987322, -1.2289896378702714, 0.39677660413713001, 4.0964936866995885, 0.38855743396313763, 0.56622111469281311, 1.7492451602644108, 0.014568305804928842, -1.1164098404168565, -1.2274922235586285]
# mean: [2.8433449053760151, -1.224015417017422, 0.4353830139274657, 4.0529307850669376, 0.43834396287328925, 0.55049728408436804, 1.7175787626030703, 0.0035235137463219745, -1.1453428558510683, -1.2586050750394293]
# covar (first 5 vars):
# [[ 2.40763 -0.27649  0.21635 -0.81232  0.3426 ]
#  [-0.27649  2.41426 -0.76605  0.05396  0.10054]
#  [ 0.21635 -0.76605  2.58648 -0.78881  1.11735]
#  [-0.81232  0.05396 -0.78881  1.9112  -0.4297 ]
#  [ 0.3426   0.10054  1.11735 -0.4297   1.55398]]
# covar (first 5 vars):
# [[ 2.17823 -0.28503  0.21506 -0.75763  0.31063]
#  [-0.28503  2.31066 -0.83511  0.10304  0.00481]
#  [ 0.21506 -0.83511  2.53285 -0.77989  1.09462]
#  [-0.75763  0.10304 -0.77989  1.7631  -0.43278]
#  [ 0.31063  0.00481  1.09462 -0.43278  1.44374]]

# %% [markdown]
# #Detailed statisics of monte-carlo on gaussian distribution
# ## with identity covar matrix

# %%
def TestMonteCarloIteration(size, variables, knn, symmetrize, power, reweightIterations):
    data = numpy.random.randn(size, variables, )
    mean = numpy.mean(data, axis = 0)
    covar = numpy.cov(data.T)
    
    toyData, _ = toymc.generateToyMonteCarlo(data, size, knn, symmetrize, power, reweightIterations)
    mean2 = numpy.mean(toyData, axis = 0)
    covar2 = numpy.cov(toyData.T)
    
    covardiff =  abs(covar - covar2)
    covarsigned = covar - covar2
    diagDeviation = numpy.trace(covardiff) * 1.0 / variables
    print "size=%5i, vars=%i"
    print "size=", size, "vars=", variables, "knn=", knn, "symmetrize=", symmetrize, "\tpower=", power,
    print "\tdiag=\t",  diagDeviation
    # print "\toutdiag=\t", (numpy.sum(covarsigned) - numpy.trace(covarsigned)) * 1.0 /  variables / (variables - 1)
    # print numpy.linalg.norm(covar - covar2)
    return diagDeviation


# Prints dependence of deviation vs different parameters
# VEEEERY SLOOOOOOOW, quite heave computations
def printToyMonteCarloParametersReport():
    """ Tests GenerateToyMonteCarlo procedure """
    
    sizes = [int( 100 * (1.7 ** i)) for i in range(10)]
    data  = [TestMonteCarloIteration(size, 15, 4, True, 2.0, 6) for size in sizes]
    print "Size sensitivity"
    plot(sizes, data)
    pylab.show()
    
    variables = [5 + 2 * x for x in range(14)]
    for knn in [5, 10, 20]:
        data  = [TestMonteCarloIteration(4000, varn, knn, True, 2.0, 6) for varn in variables]
        print "Sensitivity to number of variables, knn = ", knn
        plot(variables, data)
        pylab.show()

    powers = [1.0, 1.3, 2.2, 2.7, 4, 6]
    data  = [TestMonteCarloIteration(2500, 15, 4, True, power, 6) for power in powers]
    print "power sensitivity"
    plot(powers, data)
    pylab.show()
        
    print "Raw data as a table"
    for size in [800, 2000]:
        for variables in [10, 15, 20]:
            for knn in [5, 10, 20]:
                for symmetrize in [False, True]:
                    TestMonteCarloIteration(size, variables, knn, symmetrize, 2.0, 6)
            
    

printToyMonteCarloParametersReport()
# Out:
# size=%5i, vars=%i
# size= 100 vars= 15 knn= 4 symmetrize= True 	power= 2.0 	diag=	0.216620771451
# size=%5i, vars=%i
# size= 170 vars= 15 knn= 4 symmetrize= True 	power= 2.0 	diag=	0.176721472675
# size=%5i, vars=%i
# size= 288 vars= 15 knn= 4 symmetrize= True 	power= 2.0 	diag=	0.150532452133
# size=%5i, vars=%i
# size= 491 vars= 15 knn= 4 symmetrize= True 	power= 2.0 	diag=	0.166654500174
# size=%5i, vars=%i
# size= 835 vars= 15 knn= 4 symmetrize= True 	power= 2.0 	diag=	0.116936150291
# size=%5i, vars=%i
# size= 1419 vars= 15 knn= 4 symmetrize= True 	power= 2.0 	diag=	0.123380060983
# size=%5i, vars=%i
# size= 2413 vars= 15 knn= 4 symmetrize= True 	power= 2.0 	diag=	0.123942380117
# size=%5i, vars=%i
# size= 4103 vars= 15 knn= 4 symmetrize= True 	power= 2.0 	diag=	0.123474148993
# size=%5i, vars=%i
# size= 6975 vars= 15 knn= 4 symmetrize= True 	power= 2.0 	diag=	0.12056020047
# size=%5i, vars=%i
# size= 11858 vars= 15 knn= 4 symmetrize= True 	power= 2.0 	diag=	0.103675642135
# Size sensitivity
# size=%5i, vars=%i
# size= 4000 vars= 5 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.0423306047413
# size=%5i, vars=%i
# size= 4000 vars= 7 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.0585373344658
# size=%5i, vars=%i
# size= 4000 vars= 9 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.0766530865039
# size=%5i, vars=%i
# size= 4000 vars= 11 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.0940049293171
# size=%5i, vars=%i
# size= 4000 vars= 13 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.105472327749
# size=%5i, vars=%i
# size= 4000 vars= 15 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.117482961541
# size=%5i, vars=%i
# size= 4000 vars= 17 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.139123777237
# size=%5i, vars=%i
# size= 4000 vars= 19 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.154997755425
# size=%5i, vars=%i
# size= 4000 vars= 21 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.157912537667
# size=%5i, vars=%i
# size= 4000 vars= 23 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.165401549405
# size=%5i, vars=%i
# size= 4000 vars= 25 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.169091991581
# size=%5i, vars=%i
# size= 4000 vars= 27 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.178295080681
# size=%5i, vars=%i
# size= 4000 vars= 29 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.188545204859
# size=%5i, vars=%i
# size= 4000 vars= 31 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.191511916351
# Sensitivity to number of variables, knn =  5
# size=%5i, vars=%i
# size= 4000 vars= 5 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.0367165229213
# size=%5i, vars=%i
# size= 4000 vars= 7 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.0832395207753
# size=%5i, vars=%i
# size= 4000 vars= 9 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.0911258661841
# size=%5i, vars=%i
# size= 4000 vars= 11 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.109330726136
# size=%5i, vars=%i
# size= 4000 vars= 13 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.129800809862
# size=%5i, vars=%i
# size= 4000 vars= 15 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.157105846329
# size=%5i, vars=%i
# size= 4000 vars= 17 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.164808813857
# size=%5i, vars=%i
# size= 4000 vars= 19 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.173619924277
# size=%5i, vars=%i
# size= 4000 vars= 21 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.18291973556
# size=%5i, vars=%i
# size= 4000 vars= 23 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.187858326141
# size=%5i, vars=%i
# size= 4000 vars= 25 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.187841321288
# size=%5i, vars=%i
# size= 4000 vars= 27 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.187419441324
# size=%5i, vars=%i
# size= 4000 vars= 29 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.211451952018
# size=%5i, vars=%i
# size= 4000 vars= 31 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.208898687753
# Sensitivity to number of variables, knn =  10
# size=%5i, vars=%i
# size= 4000 vars= 5 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.0465037614046
# size=%5i, vars=%i
# size= 4000 vars= 7 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.0755902411787
# size=%5i, vars=%i
# size= 4000 vars= 9 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.108509222727
# size=%5i, vars=%i
# size= 4000 vars= 11 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.133185555079
# size=%5i, vars=%i
# size= 4000 vars= 13 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.151214529055
# size=%5i, vars=%i
# size= 4000 vars= 15 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.17216365627
# size=%5i, vars=%i
# size= 4000 vars= 17 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.185448016931
# size=%5i, vars=%i
# size= 4000 vars= 19 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.195293001594
# size=%5i, vars=%i
# size= 4000 vars= 21 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.199650256247
# size=%5i, vars=%i
# size= 4000 vars= 23 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.198094484499
# size=%5i, vars=%i
# size= 4000 vars= 25 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.211179423833
# size=%5i, vars=%i
# size= 4000 vars= 27 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.220093518074
# size=%5i, vars=%i
# size= 4000 vars= 29 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.215769954597
# size=%5i, vars=%i
# size= 4000 vars= 31 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.225029963443
# Sensitivity to number of variables, knn =  20
# size=%5i, vars=%i
# size= 2500 vars= 15 knn= 4 symmetrize= True 	power= 1.0 	diag=	0.152371494444
# size=%5i, vars=%i
# size= 2500 vars= 15 knn= 4 symmetrize= True 	power= 1.3 	diag=	0.136264736579
# size=%5i, vars=%i
# size= 2500 vars= 15 knn= 4 symmetrize= True 	power= 2.2 	diag=	0.122778838999
# size=%5i, vars=%i
# size= 2500 vars= 15 knn= 4 symmetrize= True 	power= 2.7 	diag=	0.123033597923
# size=%5i, vars=%i
# size= 2500 vars= 15 knn= 4 symmetrize= True 	power= 4 	diag=	0.106144804226
# size=%5i, vars=%i
# size= 2500 vars= 15 knn= 4 symmetrize= True 	power= 6 	diag=	0.096719041227
# power sensitivity
# Raw data as a table
# size=%5i, vars=%i
# size= 800 vars= 10 knn= 5 symmetrize= False 	power= 2.0 	diag=	0.315156042761
# size=%5i, vars=%i
# size= 800 vars= 10 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.11757380641
# size=%5i, vars=%i
# size= 800 vars= 10 knn= 10 symmetrize= False 	power= 2.0 	diag=	0.286867138603
# size=%5i, vars=%i
# size= 800 vars= 10 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.13708442554
# size=%5i, vars=%i
# size= 800 vars= 10 knn= 20 symmetrize= False 	power= 2.0 	diag=	0.337154419697
# size=%5i, vars=%i
# size= 800 vars= 10 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.18721769976
# size=%5i, vars=%i
# size= 800 vars= 15 knn= 5 symmetrize= False 	power= 2.0 	diag=	0.293465197916
# size=%5i, vars=%i
# size= 800 vars= 15 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.155588353106
# size=%5i, vars=%i
# size= 800 vars= 15 knn= 10 symmetrize= False 	power= 2.0 	diag=	0.309423593137
# size=%5i, vars=%i
# size= 800 vars= 15 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.199006109573
# size=%5i, vars=%i
# size= 800 vars= 15 knn= 20 symmetrize= False 	power= 2.0 	diag=	0.308203723139
# size=%5i, vars=%i
# size= 800 vars= 15 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.178991248132
# size=%5i, vars=%i
# size= 800 vars= 20 knn= 5 symmetrize= False 	power= 2.0 	diag=	0.3127383739
# size=%5i, vars=%i
# size= 800 vars= 20 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.185057369661
# size=%5i, vars=%i
# size= 800 vars= 20 knn= 10 symmetrize= False 	power= 2.0 	diag=	0.325359137785
# size=%5i, vars=%i
# size= 800 vars= 20 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.182134767982
# size=%5i, vars=%i
# size= 800 vars= 20 knn= 20 symmetrize= False 	power= 2.0 	diag=	0.333324783793
# size=%5i, vars=%i
# size= 800 vars= 20 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.224694577349
# size=%5i, vars=%i
# size= 2000 vars= 10 knn= 5 symmetrize= False 	power= 2.0 	diag=	0.248968976517
# size=%5i, vars=%i
# size= 2000 vars= 10 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.0958335050404
# size=%5i, vars=%i
# size= 2000 vars= 10 knn= 10 symmetrize= False 	power= 2.0 	diag=	0.266109746751
# size=%5i, vars=%i
# size= 2000 vars= 10 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.11784573565
# size=%5i, vars=%i
# size= 2000 vars= 10 knn= 20 symmetrize= False 	power= 2.0 	diag=	0.297604296617
# size=%5i, vars=%i
# size= 2000 vars= 10 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.154603345654
# size=%5i, vars=%i
# size= 2000 vars= 15 knn= 5 symmetrize= False 	power= 2.0 	diag=	0.289901964094
# size=%5i, vars=%i
# size= 2000 vars= 15 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.144557917649
# size=%5i, vars=%i
# size= 2000 vars= 15 knn= 10 symmetrize= False 	power= 2.0 	diag=	0.298106331517
# size=%5i, vars=%i
# size= 2000 vars= 15 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.156771894941
# size=%5i, vars=%i
# size= 2000 vars= 15 knn= 20 symmetrize= False 	power= 2.0 	diag=	0.29968760907
# size=%5i, vars=%i
# size= 2000 vars= 15 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.179963085087
# size=%5i, vars=%i
# size= 2000 vars= 20 knn= 5 symmetrize= False 	power= 2.0 	diag=	0.30286902904
# size=%5i, vars=%i
# size= 2000 vars= 20 knn= 5 symmetrize= True 	power= 2.0 	diag=	0.17743152893
# size=%5i, vars=%i
# size= 2000 vars= 20 knn= 10 symmetrize= False 	power= 2.0 	diag=	0.318975281301
# size=%5i, vars=%i
# size= 2000 vars= 20 knn= 10 symmetrize= True 	power= 2.0 	diag=	0.179667620978
# size=%5i, vars=%i
# size= 2000 vars= 20 knn= 20 symmetrize= False 	power= 2.0 	diag=	0.326258695981
# size=%5i, vars=%i
# size= 2000 vars= 20 knn= 20 symmetrize= True 	power= 2.0 	diag=	0.202040723124

# %%
# bck.csv
# bck_df = pandas.read_csv("/Users/axelr/Downloads/for_toy_mc/bck.csv", sep='\t')
# outDf = toymc.generateToyMonteCarloWithSpectialFeatures(bck_df, len(bck_df), \
#                             clusterization_features=["isolationd", "isolatione", "isolationf", 
#                                                     "Hlt1Dec", "Hlt2Dec", "cleaningcut", "peakingbkg"])
# outDf.to_csv("/Users/axelr/Downloads/for_toy_mc/toymc_bck.csv", sep='\t', index=False)

# %%
# sig.csv
# sig_df = pandas.read_csv("/Users/axelr/Downloads/for_toy_mc/sig.csv", sep='\t').dropna()
# sig_outDf = toymc.generateToyMonteCarloWithSpectialFeatures(sig_df, len(sig_df), \
#                             clusterization_features=["isolationd", "isolatione", "isolationf", 
#                                                     "Hlt1Dec", "Hlt2Dec", "cleaningcut", "L0Dec"])

# sig_outDf.to_csv("/Users/axelr/Downloads/for_toy_mc/toymc_sig.csv", sep='\t', index=False)

# %%
# 2011.csv
# y2011_df = pandas.read_csv("/Users/axelr/Downloads/for_toy_mc/2011.csv", sep='\t').dropna()
# out2011Df = toymc.generateToyMonteCarloWithSpectialFeatures(y2011_df, len(y2011_df), \
#                             clusterization_features=["isolationd", "isolatione", "isolationf", 
#                                                     "Hlt1Dec", "Hlt2Dec", "cleaningcut", "peakingbkg"])
# out2011Df.to_csv("/Users/axelr/Downloads/for_toy_mc/toymc_2011.csv", sep='\t', index=False)
