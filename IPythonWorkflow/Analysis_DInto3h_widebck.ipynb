# %% [markdown]
# ## About
# This notebook is devoted to analysis of decay $D \to hhh$
#
# We're looking at efficiency of background.

# %%
import pandas, numpy, reports, commonutils, uboost
import uniformgradientboosting as ugb
from supplementaryclassifiers import HidingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from IPython.display import display_html
import root_numpy
from config import ipc_profile
# Out:
# binner is ok
# normalizer is ok
# computeSignalKnnIndices is ok
# MSE variation is ok
# Compute efficiency is ok
# uniform gradient boosting is ok

# %%
def print_heading(x, level=3):
    display_html("<h%i>%s</h%i>" % (level, str(x), level), raw=True)

# %%
uniform_variables = ['D_MM']
helping_variables = ['D_BKGCAT', 'D_FD_OWNPV', 'D_TRUETAU', 'D_P', ]

train_variables = ['D_TAU', 'D_P', 'D_FD_OWNPV']

all_branches = uniform_variables + helping_variables
all_branches = list(set(all_branches))

# %% [markdown]
# ## Loading data from ROOT

# %%
def load_file(name):
    result = root_numpy.root2array('/mnt/w76/notebook/datasets/D23P/' + name, treename='DecayTree', branches=all_branches)
    return pandas.DataFrame(result)

# %%
signal1 = load_file('D2PPP_Signal_Stripped_MD.root')
signal2 = load_file('D2PPP_Signal_Stripped_MU.root')

# bg_bb = load_file('bbbar_bkg_ppp.root')
# bg_cc = load_file('ccbar_bkg_ppp.root')

bg_wbb = load_file('bbbar_bkg_ppp_wide.root')
bg_wcc = load_file('ccbar_bkg_ppp_wide.root')

# %% [markdown]
# # Different plots to ensure the quality of variables

# %%
def plot_on_df(df):
    figure(figsize=[18, 6])
    subplot(141)
    title('D_MM'),  hist(df['D_MM'])
    subplot(142)
    title('D_P'),   hist(df['D_P'], range=[0, 200000])
    subplot(143)
    title('TAU'),   hist(df['D_TRUETAU'])
    subplot(144)
    title('TAU>0'), hist(df['D_TRUETAU'], range=[0, 0.01])
    show()

print_heading('On signal')
plot_on_df(signal1)
print_heading('On background')
plot_on_df(bg_wbb)
# Out:
# <h3>On signal</h3>
# <h3>On background</h3>

# %% [markdown]
# # Applying selection rule to BCK

# %%
# bg_bb = bg_bb.query('D_BKGCAT > 20')
# bg_cc = bg_cc.query('D_BKGCAT > 20')

bg_wbb = bg_wbb.query('D_BKGCAT > 20')
bg_wcc = bg_wcc.query('D_BKGCAT > 20')

# %%
data = pandas.concat([bg_wbb, bg_wcc, signal1, signal2], ignore_index=True)
labels = numpy.concatenate([numpy.zeros(len(bg_wbb) + len(bg_wcc)), numpy.ones(len(signal1) + len(signal2))]).astype(int)

# %%
hist(numpy.array(data.D_MM[labels > 0.5]), bins=40, label='signal')
hist(numpy.array(data.D_MM[labels < 0.5]), bins=40, label='bg')
legend()

# %% [markdown]
# # Adding TAU
# $\dfrac{\beta}{\sqrt{1-\beta^2}} = \dfrac{p}{m}$
#
# $\tau = t  \sqrt{1 - \beta^2} = \dfrac{FD \sqrt{1 - \beta^2}}{ c \beta }
# = \dfrac{FD \times m}{c \times p}$

# %%
# 300 is light speed
data['D_TAU'] = data.eval('D_FD_OWNPV * D_MM / D_P / 300')

# %%
# relative error to check
values = (data.D_TAU - data.D_TRUETAU) / (abs(data.D_TRUETAU) + abs(data.D_TAU))
hist(numpy.array(values[data.D_TRUETAU > 0.] ), bins=30)
pass

# %% [markdown]
# # Adding Dalitz variables
# pay attention that log of pdf is plotted, not pdf itself

# %%
# def compute_inv_mass(df, name1, name2):
#     # adding 4-vectors
#     pe = df[name1 + 'E'] + df[name2 + 'E']
#     px = df[name1 + 'X'] + df[name2 + 'X']
#     py = df[name1 + 'Y'] + df[name2 + 'Y']
#     pz = df[name1 + 'Z'] + df[name2 + 'Z']
#     # computing its mass
#     return pe*pe - px*px - py*py - pz*pz

# %%
# data['m12'] = compute_inv_mass(data, 'p1_P', 'p2_P')
# data['m13'] = compute_inv_mass(data, 'p1_P', 'p3_P')
# data['m23'] = compute_inv_mass(data, 'p2_P', 'p3_P')

# %%
# def plotDistribution2D(var_name1, var_name2, data_frame, bins=30):
#     """The function to plot 2D distribution histograms"""
#     H, x, y = pylab.histogram2d(numpy.array(data_frame[var_name1]), 
#                                 numpy.array(data_frame[var_name2]), bins=bins)
#     pylab.xlabel(var_name1), pylab.ylabel(var_name2)
#     pylab.pcolor(x, y, log(1 + H), cmap=cm.Blues)
#     pylab.colorbar()

# pylab.figure(figsize=(16, 6))
# subplot(1, 2, 1), pylab.title("signal (log of pdf)"),       plotDistribution2D("m12", "m23", data[labels > 0.5])
# subplot(1, 2, 2), pylab.title("background (log of pdf)"),   plotDistribution2D("m12", "m23", data[labels < 0.5])
# pass

# %% [markdown]
# # Splitting data

# %%
trainX, testX, trainY, testY = commonutils.train_test_split(data, labels, train_size=0.5)

# %%
# # test mode
# trainX, testX, trainY, testY = commonutils.train_test_split(data, labels, train_size=0.01, test_size=0.05)
# print len(trainX), len(testX)
# print sum(labels) * 1. / len(labels)

# %% [markdown]
# # Selecting the mass for train bck < 1850
# we first randomly split the data, the we reject bck events in train dataset, what have mass greater than 1850

# %%
mask = (trainY == 1) | (trainX.D_MM < 1850)
trainX = trainX.ix[mask, :]
trainY = trainY[numpy.array(mask)]

# %%
print len(trainX), len(testX)
figure(figsize=[16, 6])
m_range = [1750, 2100]
subplot(121), title('train, bck'), hist(numpy.array(trainX.D_MM[trainY == 0])), xlim(m_range)
subplot(122), title('test,  bck'), hist(numpy.array(testX.D_MM[testY == 0])  ), xlim(m_range)
pass
# Out:
# 39280 46894

# %% [markdown]
# # Uniformity in mass of D
# ## Setting up classifiers

# %%
tree_params = {'max_depth': 3, 'min_samples_leaf': 30}
base_tree = DecisionTreeClassifier(**tree_params)
n_estimators = 200

# %%
classifiers = reports.ClassifiersDict()
# for depth in [3, 8, 15, 20]:
#     tree = DecisionTreeClassifier(max_depth=depth, min_samples_leaf=30)
#     classifiers['ada' + str(depth)] = HidingClassifier(train_variables=train_variables, 
#                 base_estimator=AdaBoostClassifier(base_estimator=tree, n_estimators=n_estimators))

classifiers['Ada'] = HidingClassifier(train_variables=train_variables, 
                base_estimator=AdaBoostClassifier(base_estimator=base_tree, n_estimators=n_estimators))

knnloss = ugb.SimpleKnnLossFunction(uniform_variables, knn=20)
classifiers['uGB']    = ugb.MyGradientBoostingClassifier(loss=knnloss, n_estimators=n_estimators,
                                                         learning_rate=0.5, train_variables=train_variables, **tree_params)

flatnessloss = ugb.FlatnessLossFunction(uniform_variables, ada_coefficient=0.05, uniform_label=[0,1], power=2.5)
classifiers['uGB+FL'] = ugb.MyGradientBoostingClassifier(loss=flatnessloss, n_estimators=n_estimators, 
                                                         learning_rate=0.2, train_variables=train_variables, **tree_params)
classifiers.fit(trainX, trainY, ipc_profile=ipc_profile)
pass
# Out:
# We spent 38.90 seconds on parallel training

# %%
# %%time
classifiers['uBoost'] = uboost.uBoostClassifier(uniform_variables=uniform_variables, train_variables=train_variables,
            n_estimators=n_estimators, base_estimator=base_tree, smoothing=0.,
            efficiency_steps=10, ipc_profile=ipc_profile).fit(trainX, trainY)
# Out:
# CPU times: user 5.07 s, sys: 400 ms, total: 5.47 s
# Wall time: 39.9 s

# %% [markdown]
# ## Results

# %%
preds = classifiers.test_on(testX, testY, low_memory=False)

# %% [markdown]
# ### Uniformity on signal

# %%
preds.efficiency(uniform_variables=uniform_variables, label=1)

# %% [markdown]
# ###Uniformity on background

# %%
preds.efficiency(uniform_variables=uniform_variables, label=0)

# %%
preds.roc()

# %%
figure(figsize=(18, 7))
subplot(131), title('Learning curves'), preds.learning_curves()
subplot(132), title('MSE curves:sig') , preds.mse_curves(uniform_variables=uniform_variables, step=3, label=1)
subplot(133), title('MSE curves:bg')  , preds.mse_curves(uniform_variables=uniform_variables, step=3, label=0)
show()

# %%
# the center is mass of strange D-meson
Ds_mass = 1968.47
figure(figsize=(16, 7))
subplot(121), preds.correlation_curves(var_name=uniform_variables[0], center=Ds_mass, label=1)
subplot(122), preds.correlation_curves(var_name=uniform_variables[0], center=Ds_mass, label=0)
show()

# %%
preds.learning_curves(commonutils.optimal_sensitivity)
ylabel('sensitivity $ = s / \sqrt{s+b}$')

# %% [markdown]
# # The list of branches

# %%
sorted(set(root_numpy.list_branches('/mnt/w76/notebook/datasets/D23P/bbbar_bkg_ppp.root')) \
.intersection(root_numpy.list_branches('/mnt/w76/notebook/datasets/D23P/ccbar_bkg_ppp.root')) \
.intersection(root_numpy.list_branches('/mnt/w76/notebook/datasets/D23P/D2PPP_Signal_Stripped_MD.root'))
)
# Out:
# ['BCID',
#  'BCType',
#  'DHlt1DiMuonHighMassDecision_Dec',
#  'DHlt1DiMuonHighMassDecision_TIS',
#  'DHlt1DiMuonHighMassDecision_TOS',
#  'DHlt1DiMuonLowMassDecision_Dec',
#  'DHlt1DiMuonLowMassDecision_TIS',
#  'DHlt1DiMuonLowMassDecision_TOS',
#  'DHlt1Global_Dec',
#  'DHlt1Global_TIS',
#  'DHlt1Global_TOS',
#  'DHlt1Phys_Dec',
#  'DHlt1Phys_TIS',
#  'DHlt1Phys_TOS',
#  'DHlt1SingleMuonHighPTDecision_Dec',
#  'DHlt1SingleMuonHighPTDecision_TIS',
#  'DHlt1SingleMuonHighPTDecision_TOS',
#  'DHlt1SingleMuonNoIPDecision_Dec',
#  'DHlt1SingleMuonNoIPDecision_TIS',
#  'DHlt1SingleMuonNoIPDecision_TOS',
#  'DHlt1TrackAllL0Decision_Dec',
#  'DHlt1TrackAllL0Decision_TIS',
#  'DHlt1TrackAllL0Decision_TOS',
#  'DHlt1TrackMuonDecision_Dec',
#  'DHlt1TrackMuonDecision_TIS',
#  'DHlt1TrackMuonDecision_TOS',
#  'DHlt1TrackPhotonDecision_Dec',
#  'DHlt1TrackPhotonDecision_TIS',
#  'DHlt1TrackPhotonDecision_TOS',
#  'DHlt2CharmHadD2HHHDecision_Dec',
#  'DHlt2CharmHadD2HHHDecision_TIS',
#  'DHlt2CharmHadD2HHHDecision_TOS',
#  'DHlt2CharmHadD2HHHWideMassDecision_Dec',
#  'DHlt2CharmHadD2HHHWideMassDecision_TIS',
#  'DHlt2CharmHadD2HHHWideMassDecision_TOS',
#  'DHlt2Global_Dec',
#  'DHlt2Global_TIS',
#  'DHlt2Global_TOS',
#  'DHlt2Phys_Dec',
#  'DHlt2Phys_TIS',
#  'DHlt2Phys_TOS',
#  'DL0DiMuonDecision_Dec',
#  'DL0DiMuonDecision_TIS',
#  'DL0DiMuonDecision_TOS',
#  'DL0DiMuonNoSPDDecision_Dec',
#  'DL0DiMuonNoSPDDecision_TIS',
#  'DL0DiMuonNoSPDDecision_TOS',
#  'DL0ElectronDecision_Dec',
#  'DL0ElectronDecision_TIS',
#  'DL0ElectronDecision_TOS',
#  'DL0ElectronNoSPDDecision_Dec',
#  'DL0ElectronNoSPDDecision_TIS',
#  'DL0ElectronNoSPDDecision_TOS',
#  'DL0Global_Dec',
#  'DL0Global_TIS',
#  'DL0Global_TOS',
#  'DL0HadronDecision_Dec',
#  'DL0HadronDecision_TIS',
#  'DL0HadronDecision_TOS',
#  'DL0HadronNoSPDDecision_Dec',
#  'DL0HadronNoSPDDecision_TIS',
#  'DL0HadronNoSPDDecision_TOS',
#  'DL0MuonDecision_Dec',
#  'DL0MuonDecision_TIS',
#  'DL0MuonDecision_TOS',
#  'DL0MuonNoSPDDecision_Dec',
#  'DL0MuonNoSPDDecision_TIS',
#  'DL0MuonNoSPDDecision_TOS',
#  'DL0PhotonDecision_Dec',
#  'DL0PhotonDecision_TIS',
#  'DL0PhotonDecision_TOS',
#  'DL0PhotonNoSPDDecision_Dec',
#  'DL0PhotonNoSPDDecision_TIS',
#  'DL0PhotonNoSPDDecision_TOS',
#  'DStrippingGlobal_Dec',
#  'DStrippingGlobal_TIS',
#  'DStrippingGlobal_TOS',
#  'D_BKGCAT',
#  'D_BPVIPCHI2',
#  'D_BPVTRGPOINTING',
#  'D_BPVVD',
#  'D_DIRA_OWNPV',
#  'D_DIRA_TOPPV',
#  'D_DOCA',
#  'D_DOCA12',
#  'D_DOCA13',
#  'D_DOCA23',
#  'D_ENDVERTEX_CHI2',
#  'D_ENDVERTEX_COV_',
#  'D_ENDVERTEX_NDOF',
#  'D_ENDVERTEX_X',
#  'D_ENDVERTEX_XERR',
#  'D_ENDVERTEX_Y',
#  'D_ENDVERTEX_YERR',
#  'D_ENDVERTEX_Z',
#  'D_ENDVERTEX_ZERR',
#  'D_FDCHI2_OWNPV',
#  'D_FDCHI2_TOPPV',
#  'D_FD_OWNPV',
#  'D_FD_TOPPV',
#  'D_ID',
#  'D_IPCHI2_OWNPV',
#  'D_IPCHI2_TOPPV',
#  'D_IP_OWNPV',
#  'D_IP_TOPPV',
#  'D_LOKI_ETA',
#  'D_LOKI_MM',
#  'D_LOKI_PHI',
#  'D_M',
#  'D_MC_GD_GD_MOTHER_ID',
#  'D_MC_GD_GD_MOTHER_KEY',
#  'D_MC_GD_MOTHER_ID',
#  'D_MC_GD_MOTHER_KEY',
#  'D_MC_MOTHER_ID',
#  'D_MC_MOTHER_KEY',
#  'D_MINIP',
#  'D_MINIPCHI2',
#  'D_MINIPCHI2NEXTBEST',
#  'D_MINIPNEXTBEST',
#  'D_MINVDDV',
#  'D_MM',
#  'D_MMERR',
#  'D_OSCIL',
#  'D_OWNPV_CHI2',
#  'D_OWNPV_COV_',
#  'D_OWNPV_NDOF',
#  'D_OWNPV_X',
#  'D_OWNPV_XERR',
#  'D_OWNPV_Y',
#  'D_OWNPV_YERR',
#  'D_OWNPV_Z',
#  'D_OWNPV_ZERR',
#  'D_P',
#  'D_PE',
#  'D_PT',
#  'D_PX',
#  'D_PY',
#  'D_PZ',
#  'D_TOPPV_CHI2',
#  'D_TOPPV_COV_',
#  'D_TOPPV_NDOF',
#  'D_TOPPV_X',
#  'D_TOPPV_XERR',
#  'D_TOPPV_Y',
#  'D_TOPPV_YERR',
#  'D_TOPPV_Z',
#  'D_TOPPV_ZERR',
#  'D_TRUEENDVERTEX_X',
#  'D_TRUEENDVERTEX_Y',
#  'D_TRUEENDVERTEX_Z',
#  'D_TRUEID',
#  'D_TRUEISSTABLE',
#  'D_TRUEORIGINVERTEX_X',
#  'D_TRUEORIGINVERTEX_Y',
#  'D_TRUEORIGINVERTEX_Z',
#  'D_TRUEPT',
#  'D_TRUEP_E',
#  'D_TRUEP_X',
#  'D_TRUEP_Y',
#  'D_TRUEP_Z',
#  'D_TRUETAU',
#  'D_VFASPFVCHI2',
#  'D_dcaSVPV_CHI2',
#  'D_vchi2',
#  'EventInSequence',
#  'GpsTime',
#  'HLTTCK',
#  'Hlt1Global',
#  'Hlt2Global',
#  'L0DUTCK',
#  'L0Global',
#  'OdinTCK',
#  'PVCHI2',
#  'PVNDOF',
#  'PVNTRACKS',
#  'PVX',
#  'PVXERR',
#  'PVY',
#  'PVYERR',
#  'PVZ',
#  'PVZERR',
#  'Polarity',
#  'Primaries',
#  'eventNumber',
#  'nCandidate',
#  'nDownstream',
#  'nLongTracks',
#  'nPV',
#  'nSPDHits',
#  'nTTracks',
#  'nVeloTracks',
#  'p1Hlt1DiMuonHighMassDecision_Dec',
#  'p1Hlt1DiMuonHighMassDecision_TIS',
#  'p1Hlt1DiMuonHighMassDecision_TOS',
#  'p1Hlt1DiMuonLowMassDecision_Dec',
#  'p1Hlt1DiMuonLowMassDecision_TIS',
#  'p1Hlt1DiMuonLowMassDecision_TOS',
#  'p1Hlt1Global_Dec',
#  'p1Hlt1Global_TIS',
#  'p1Hlt1Global_TOS',
#  'p1Hlt1Phys_Dec',
#  'p1Hlt1Phys_TIS',
#  'p1Hlt1Phys_TOS',
#  'p1Hlt1SingleMuonHighPTDecision_Dec',
#  'p1Hlt1SingleMuonHighPTDecision_TIS',
#  'p1Hlt1SingleMuonHighPTDecision_TOS',
#  'p1Hlt1SingleMuonNoIPDecision_Dec',
#  'p1Hlt1SingleMuonNoIPDecision_TIS',
#  'p1Hlt1SingleMuonNoIPDecision_TOS',
#  'p1Hlt1TrackAllL0Decision_Dec',
#  'p1Hlt1TrackAllL0Decision_TIS',
#  'p1Hlt1TrackAllL0Decision_TOS',
#  'p1Hlt1TrackMuonDecision_Dec',
#  'p1Hlt1TrackMuonDecision_TIS',
#  'p1Hlt1TrackMuonDecision_TOS',
#  'p1Hlt1TrackPhotonDecision_Dec',
#  'p1Hlt1TrackPhotonDecision_TIS',
#  'p1Hlt1TrackPhotonDecision_TOS',
#  'p1Hlt2CharmHadD2HHHDecision_Dec',
#  'p1Hlt2CharmHadD2HHHDecision_TIS',
#  'p1Hlt2CharmHadD2HHHDecision_TOS',
#  'p1Hlt2CharmHadD2HHHWideMassDecision_Dec',
#  'p1Hlt2CharmHadD2HHHWideMassDecision_TIS',
#  'p1Hlt2CharmHadD2HHHWideMassDecision_TOS',
#  'p1Hlt2Global_Dec',
#  'p1Hlt2Global_TIS',
#  'p1Hlt2Global_TOS',
#  'p1Hlt2Phys_Dec',
#  'p1Hlt2Phys_TIS',
#  'p1Hlt2Phys_TOS',
#  'p1L0DiMuonDecision_Dec',
#  'p1L0DiMuonDecision_TIS',
#  'p1L0DiMuonDecision_TOS',
#  'p1L0DiMuonNoSPDDecision_Dec',
#  'p1L0DiMuonNoSPDDecision_TIS',
#  'p1L0DiMuonNoSPDDecision_TOS',
#  'p1L0ElectronDecision_Dec',
#  'p1L0ElectronDecision_TIS',
#  'p1L0ElectronDecision_TOS',
#  'p1L0ElectronNoSPDDecision_Dec',
#  'p1L0ElectronNoSPDDecision_TIS',
#  'p1L0ElectronNoSPDDecision_TOS',
#  'p1L0Global_Dec',
#  'p1L0Global_TIS',
#  'p1L0Global_TOS',
#  'p1L0HadronDecision_Dec',
#  'p1L0HadronDecision_TIS',
#  'p1L0HadronDecision_TOS',
#  'p1L0HadronNoSPDDecision_Dec',
#  'p1L0HadronNoSPDDecision_TIS',
#  'p1L0HadronNoSPDDecision_TOS',
#  'p1L0MuonDecision_Dec',
#  'p1L0MuonDecision_TIS',
#  'p1L0MuonDecision_TOS',
#  'p1L0MuonNoSPDDecision_Dec',
#  'p1L0MuonNoSPDDecision_TIS',
#  'p1L0MuonNoSPDDecision_TOS',
#  'p1L0PhotonDecision_Dec',
#  'p1L0PhotonDecision_TIS',
#  'p1L0PhotonDecision_TOS',
#  'p1L0PhotonNoSPDDecision_Dec',
#  'p1L0PhotonNoSPDDecision_TIS',
#  'p1L0PhotonNoSPDDecision_TOS',
#  'p1StrippingGlobal_Dec',
#  'p1StrippingGlobal_TIS',
#  'p1StrippingGlobal_TOS',
#  'p1_Aerogel_Phi',
#  'p1_Aerogel_Rho',
#  'p1_Aerogel_X',
#  'p1_Aerogel_Y',
#  'p1_Aerogel_Z',
#  'p1_BPVIPCHI2',
#  'p1_BPVTRGPOINTING',
#  'p1_BPVVD',
#  'p1_DOCA',
#  'p1_DOCA12',
#  'p1_DOCA13',
#  'p1_DOCA23',
#  'p1_ID',
#  'p1_IPCHI2_ORIVX',
#  'p1_IPCHI2_OWNPV',
#  'p1_IPCHI2_TOPPV',
#  'p1_IP_ORIVX',
#  'p1_IP_OWNPV',
#  'p1_IP_TOPPV',
#  'p1_LOKI_ETA',
#  'p1_LOKI_MM',
#  'p1_LOKI_PHI',
#  'p1_M',
#  'p1_MC_GD_GD_MOTHER_ID',
#  'p1_MC_GD_GD_MOTHER_KEY',
#  'p1_MC_GD_MOTHER_ID',
#  'p1_MC_GD_MOTHER_KEY',
#  'p1_MC_MOTHER_ID',
#  'p1_MC_MOTHER_KEY',
#  'p1_MINIP',
#  'p1_MINIPCHI2',
#  'p1_MINIPCHI2NEXTBEST',
#  'p1_MINIPNEXTBEST',
#  'p1_MINVDDV',
#  'p1_ORIVX_CHI2',
#  'p1_ORIVX_COV_',
#  'p1_ORIVX_NDOF',
#  'p1_ORIVX_X',
#  'p1_ORIVX_XERR',
#  'p1_ORIVX_Y',
#  'p1_ORIVX_YERR',
#  'p1_ORIVX_Z',
#  'p1_ORIVX_ZERR',
#  'p1_OSCIL',
#  'p1_OWNPV_CHI2',
#  'p1_OWNPV_COV_',
#  'p1_OWNPV_NDOF',
#  'p1_OWNPV_X',
#  'p1_OWNPV_XERR',
#  'p1_OWNPV_Y',
#  'p1_OWNPV_YERR',
#  'p1_OWNPV_Z',
#  'p1_OWNPV_ZERR',
#  'p1_P',
#  'p1_PE',
#  'p1_PIDK',
#  'p1_PIDe',
#  'p1_PIDmu',
#  'p1_PIDp',
#  'p1_PT',
#  'p1_PX',
#  'p1_PY',
#  'p1_PZ',
#  'p1_ProbNNe',
#  'p1_ProbNNghost',
#  'p1_ProbNNk',
#  'p1_ProbNNmu',
#  'p1_ProbNNp',
#  'p1_ProbNNpi',
#  'p1_RICH1GasUsed',
#  'p1_RICH2GasUsed',
#  'p1_RICHAerogelUsed',
#  'p1_RICHBestID',
#  'p1_RICHDLLK',
#  'p1_RICHDLLbt',
#  'p1_RICHDLLe',
#  'p1_RICHDLLmu',
#  'p1_RICHDLLp',
#  'p1_RICHDLLpi',
#  'p1_RICHThreshold',
#  'p1_RICHThresholdEl',
#  'p1_RICHThresholdKa',
#  'p1_RICHThresholdMu',
#  'p1_RICHThresholdPi',
#  'p1_RICHThresholdPr',
#  'p1_Rich1Gas_Phi',
#  'p1_Rich1Gas_Rho',
#  'p1_Rich1Gas_X',
#  'p1_Rich1Gas_Y',
#  'p1_Rich1Gas_Z',
#  'p1_Rich2Gas_Phi',
#  'p1_Rich2Gas_Rho',
#  'p1_Rich2Gas_X',
#  'p1_Rich2Gas_Y',
#  'p1_Rich2Gas_Z',
#  'p1_TOPPV_CHI2',
#  'p1_TOPPV_COV_',
#  'p1_TOPPV_NDOF',
#  'p1_TOPPV_X',
#  'p1_TOPPV_XERR',
#  'p1_TOPPV_Y',
#  'p1_TOPPV_YERR',
#  'p1_TOPPV_Z',
#  'p1_TOPPV_ZERR',
#  'p1_TRACK_CHI2',
#  'p1_TRACK_CHI2NDOF',
#  'p1_TRACK_CloneDist',
#  'p1_TRACK_Eta',
#  'p1_TRACK_GhostProb',
#  'p1_TRACK_Key',
#  'p1_TRACK_MatchCHI2',
#  'p1_TRACK_NDOF',
#  'p1_TRACK_PCHI2',
#  'p1_TRACK_Phi',
#  'p1_TRACK_TCHI2NDOF',
#  'p1_TRACK_Type',
#  'p1_TRACK_VeloCHI2NDOF',
#  'p1_TRUEENDVERTEX_X',
#  'p1_TRUEENDVERTEX_Y',
#  'p1_TRUEENDVERTEX_Z',
#  'p1_TRUEID',
#  'p1_TRUEISSTABLE',
#  'p1_TRUEORIGINVERTEX_X',
#  'p1_TRUEORIGINVERTEX_Y',
#  'p1_TRUEORIGINVERTEX_Z',
#  'p1_TRUEPT',
#  'p1_TRUEP_E',
#  'p1_TRUEP_X',
#  'p1_TRUEP_Y',
#  'p1_TRUEP_Z',
#  'p1_TRUETAU',
#  'p1_VELO_UTID',
#  'p1_VFASPFVCHI2',
#  'p1_dcaSVPV_CHI2',
#  'p1_hasCalo',
#  'p1_hasMuon',
#  'p1_hasRich',
#  'p1_isMuon',
#  'p1_vchi2',
#  'p2Hlt1DiMuonHighMassDecision_Dec',
#  'p2Hlt1DiMuonHighMassDecision_TIS',
#  'p2Hlt1DiMuonHighMassDecision_TOS',
#  'p2Hlt1DiMuonLowMassDecision_Dec',
#  'p2Hlt1DiMuonLowMassDecision_TIS',
#  'p2Hlt1DiMuonLowMassDecision_TOS',
#  'p2Hlt1Global_Dec',
#  'p2Hlt1Global_TIS',
#  'p2Hlt1Global_TOS',
#  'p2Hlt1Phys_Dec',
#  'p2Hlt1Phys_TIS',
#  'p2Hlt1Phys_TOS',
#  'p2Hlt1SingleMuonHighPTDecision_Dec',
#  'p2Hlt1SingleMuonHighPTDecision_TIS',
#  'p2Hlt1SingleMuonHighPTDecision_TOS',
#  'p2Hlt1SingleMuonNoIPDecision_Dec',
#  'p2Hlt1SingleMuonNoIPDecision_TIS',
#  'p2Hlt1SingleMuonNoIPDecision_TOS',
#  'p2Hlt1TrackAllL0Decision_Dec',
#  'p2Hlt1TrackAllL0Decision_TIS',
#  'p2Hlt1TrackAllL0Decision_TOS',
#  'p2Hlt1TrackMuonDecision_Dec',
#  'p2Hlt1TrackMuonDecision_TIS',
#  'p2Hlt1TrackMuonDecision_TOS',
#  'p2Hlt1TrackPhotonDecision_Dec',
#  'p2Hlt1TrackPhotonDecision_TIS',
#  'p2Hlt1TrackPhotonDecision_TOS',
#  'p2Hlt2CharmHadD2HHHDecision_Dec',
#  'p2Hlt2CharmHadD2HHHDecision_TIS',
#  'p2Hlt2CharmHadD2HHHDecision_TOS',
#  'p2Hlt2CharmHadD2HHHWideMassDecision_Dec',
#  'p2Hlt2CharmHadD2HHHWideMassDecision_TIS',
#  'p2Hlt2CharmHadD2HHHWideMassDecision_TOS',
#  'p2Hlt2Global_Dec',
#  'p2Hlt2Global_TIS',
#  'p2Hlt2Global_TOS',
#  'p2Hlt2Phys_Dec',
#  'p2Hlt2Phys_TIS',
#  'p2Hlt2Phys_TOS',
#  'p2L0DiMuonDecision_Dec',
#  'p2L0DiMuonDecision_TIS',
#  'p2L0DiMuonDecision_TOS',
#  'p2L0DiMuonNoSPDDecision_Dec',
#  'p2L0DiMuonNoSPDDecision_TIS',
#  'p2L0DiMuonNoSPDDecision_TOS',
#  'p2L0ElectronDecision_Dec',
#  'p2L0ElectronDecision_TIS',
#  'p2L0ElectronDecision_TOS',
#  'p2L0ElectronNoSPDDecision_Dec',
#  'p2L0ElectronNoSPDDecision_TIS',
#  'p2L0ElectronNoSPDDecision_TOS',
#  'p2L0Global_Dec',
#  'p2L0Global_TIS',
#  'p2L0Global_TOS',
#  'p2L0HadronDecision_Dec',
#  'p2L0HadronDecision_TIS',
#  'p2L0HadronDecision_TOS',
#  'p2L0HadronNoSPDDecision_Dec',
#  'p2L0HadronNoSPDDecision_TIS',
#  'p2L0HadronNoSPDDecision_TOS',
#  'p2L0MuonDecision_Dec',
#  'p2L0MuonDecision_TIS',
#  'p2L0MuonDecision_TOS',
#  'p2L0MuonNoSPDDecision_Dec',
#  'p2L0MuonNoSPDDecision_TIS',
#  'p2L0MuonNoSPDDecision_TOS',
#  'p2L0PhotonDecision_Dec',
#  'p2L0PhotonDecision_TIS',
#  'p2L0PhotonDecision_TOS',
#  'p2L0PhotonNoSPDDecision_Dec',
#  'p2L0PhotonNoSPDDecision_TIS',
#  'p2L0PhotonNoSPDDecision_TOS',
#  'p2StrippingGlobal_Dec',
#  'p2StrippingGlobal_TIS',
#  'p2StrippingGlobal_TOS',
#  'p2_Aerogel_Phi',
#  'p2_Aerogel_Rho',
#  'p2_Aerogel_X',
#  'p2_Aerogel_Y',
#  'p2_Aerogel_Z',
#  'p2_BPVIPCHI2',
#  'p2_BPVTRGPOINTING',
#  'p2_BPVVD',
#  'p2_DOCA',
#  'p2_DOCA12',
#  'p2_DOCA13',
#  'p2_DOCA23',
#  'p2_ID',
#  'p2_IPCHI2_ORIVX',
#  'p2_IPCHI2_OWNPV',
#  'p2_IPCHI2_TOPPV',
#  'p2_IP_ORIVX',
#  'p2_IP_OWNPV',
#  'p2_IP_TOPPV',
#  'p2_LOKI_ETA',
#  'p2_LOKI_MM',
#  'p2_LOKI_PHI',
#  'p2_M',
#  'p2_MC_GD_GD_MOTHER_ID',
#  'p2_MC_GD_GD_MOTHER_KEY',
#  'p2_MC_GD_MOTHER_ID',
#  'p2_MC_GD_MOTHER_KEY',
#  'p2_MC_MOTHER_ID',
#  'p2_MC_MOTHER_KEY',
#  'p2_MINIP',
#  'p2_MINIPCHI2',
#  'p2_MINIPCHI2NEXTBEST',
#  'p2_MINIPNEXTBEST',
#  'p2_MINVDDV',
#  'p2_ORIVX_CHI2',
#  'p2_ORIVX_COV_',
#  'p2_ORIVX_NDOF',
#  'p2_ORIVX_X',
#  'p2_ORIVX_XERR',
#  'p2_ORIVX_Y',
#  'p2_ORIVX_YERR',
#  'p2_ORIVX_Z',
#  'p2_ORIVX_ZERR',
#  'p2_OSCIL',
#  'p2_OWNPV_CHI2',
#  'p2_OWNPV_COV_',
#  'p2_OWNPV_NDOF',
#  'p2_OWNPV_X',
#  'p2_OWNPV_XERR',
#  'p2_OWNPV_Y',
#  'p2_OWNPV_YERR',
#  'p2_OWNPV_Z',
#  'p2_OWNPV_ZERR',
#  'p2_P',
#  'p2_PE',
#  'p2_PIDK',
#  'p2_PIDe',
#  'p2_PIDmu',
#  'p2_PIDp',
#  'p2_PT',
#  'p2_PX',
#  'p2_PY',
#  'p2_PZ',
#  'p2_ProbNNe',
#  'p2_ProbNNghost',
#  'p2_ProbNNk',
#  'p2_ProbNNmu',
#  'p2_ProbNNp',
#  'p2_ProbNNpi',
#  'p2_RICH1GasUsed',
#  'p2_RICH2GasUsed',
#  'p2_RICHAerogelUsed',
#  'p2_RICHBestID',
#  'p2_RICHDLLK',
#  'p2_RICHDLLbt',
#  'p2_RICHDLLe',
#  'p2_RICHDLLmu',
#  'p2_RICHDLLp',
#  'p2_RICHDLLpi',
#  'p2_RICHThreshold',
#  'p2_RICHThresholdEl',
#  'p2_RICHThresholdKa',
#  'p2_RICHThresholdMu',
#  'p2_RICHThresholdPi',
#  'p2_RICHThresholdPr',
#  'p2_Rich1Gas_Phi',
#  'p2_Rich1Gas_Rho',
#  'p2_Rich1Gas_X',
#  'p2_Rich1Gas_Y',
#  'p2_Rich1Gas_Z',
#  'p2_Rich2Gas_Phi',
#  'p2_Rich2Gas_Rho',
#  'p2_Rich2Gas_X',
#  'p2_Rich2Gas_Y',
#  'p2_Rich2Gas_Z',
#  'p2_TOPPV_CHI2',
#  'p2_TOPPV_COV_',
#  'p2_TOPPV_NDOF',
#  'p2_TOPPV_X',
#  'p2_TOPPV_XERR',
#  'p2_TOPPV_Y',
#  'p2_TOPPV_YERR',
#  'p2_TOPPV_Z',
#  'p2_TOPPV_ZERR',
#  'p2_TRACK_CHI2',
#  'p2_TRACK_CHI2NDOF',
#  'p2_TRACK_CloneDist',
#  'p2_TRACK_Eta',
#  'p2_TRACK_GhostProb',
#  'p2_TRACK_Key',
#  'p2_TRACK_MatchCHI2',
#  'p2_TRACK_NDOF',
#  'p2_TRACK_PCHI2',
#  'p2_TRACK_Phi',
#  'p2_TRACK_TCHI2NDOF',
#  'p2_TRACK_Type',
#  'p2_TRACK_VeloCHI2NDOF',
#  'p2_TRUEENDVERTEX_X',
#  'p2_TRUEENDVERTEX_Y',
#  'p2_TRUEENDVERTEX_Z',
#  'p2_TRUEID',
#  'p2_TRUEISSTABLE',
#  'p2_TRUEORIGINVERTEX_X',
#  'p2_TRUEORIGINVERTEX_Y',
#  'p2_TRUEORIGINVERTEX_Z',
#  'p2_TRUEPT',
#  'p2_TRUEP_E',
#  'p2_TRUEP_X',
#  'p2_TRUEP_Y',
#  'p2_TRUEP_Z',
#  'p2_TRUETAU',
#  'p2_VELO_UTID',
#  'p2_VFASPFVCHI2',
#  'p2_dcaSVPV_CHI2',
#  'p2_hasCalo',
#  'p2_hasMuon',
#  'p2_hasRich',
#  'p2_isMuon',
#  'p2_vchi2',
#  'p3Hlt1DiMuonHighMassDecision_Dec',
#  'p3Hlt1DiMuonHighMassDecision_TIS',
#  'p3Hlt1DiMuonHighMassDecision_TOS',
#  'p3Hlt1DiMuonLowMassDecision_Dec',
#  'p3Hlt1DiMuonLowMassDecision_TIS',
#  'p3Hlt1DiMuonLowMassDecision_TOS',
#  'p3Hlt1Global_Dec',
#  'p3Hlt1Global_TIS',
#  'p3Hlt1Global_TOS',
#  'p3Hlt1Phys_Dec',
#  'p3Hlt1Phys_TIS',
#  'p3Hlt1Phys_TOS',
#  'p3Hlt1SingleMuonHighPTDecision_Dec',
#  'p3Hlt1SingleMuonHighPTDecision_TIS',
#  'p3Hlt1SingleMuonHighPTDecision_TOS',
#  'p3Hlt1SingleMuonNoIPDecision_Dec',
#  'p3Hlt1SingleMuonNoIPDecision_TIS',
#  'p3Hlt1SingleMuonNoIPDecision_TOS',
#  'p3Hlt1TrackAllL0Decision_Dec',
#  'p3Hlt1TrackAllL0Decision_TIS',
#  'p3Hlt1TrackAllL0Decision_TOS',
#  'p3Hlt1TrackMuonDecision_Dec',
#  'p3Hlt1TrackMuonDecision_TIS',
#  'p3Hlt1TrackMuonDecision_TOS',
#  'p3Hlt1TrackPhotonDecision_Dec',
#  'p3Hlt1TrackPhotonDecision_TIS',
#  'p3Hlt1TrackPhotonDecision_TOS',
#  'p3Hlt2CharmHadD2HHHDecision_Dec',
#  'p3Hlt2CharmHadD2HHHDecision_TIS',
#  'p3Hlt2CharmHadD2HHHDecision_TOS',
#  'p3Hlt2CharmHadD2HHHWideMassDecision_Dec',
#  'p3Hlt2CharmHadD2HHHWideMassDecision_TIS',
#  'p3Hlt2CharmHadD2HHHWideMassDecision_TOS',
#  'p3Hlt2Global_Dec',
#  'p3Hlt2Global_TIS',
#  'p3Hlt2Global_TOS',
#  'p3Hlt2Phys_Dec',
#  'p3Hlt2Phys_TIS',
#  'p3Hlt2Phys_TOS',
#  'p3L0DiMuonDecision_Dec',
#  'p3L0DiMuonDecision_TIS',
#  'p3L0DiMuonDecision_TOS',
#  'p3L0DiMuonNoSPDDecision_Dec',
#  'p3L0DiMuonNoSPDDecision_TIS',
#  'p3L0DiMuonNoSPDDecision_TOS',
#  'p3L0ElectronDecision_Dec',
#  'p3L0ElectronDecision_TIS',
#  'p3L0ElectronDecision_TOS',
#  'p3L0ElectronNoSPDDecision_Dec',
#  'p3L0ElectronNoSPDDecision_TIS',
#  'p3L0ElectronNoSPDDecision_TOS',
#  'p3L0Global_Dec',
#  'p3L0Global_TIS',
#  'p3L0Global_TOS',
#  'p3L0HadronDecision_Dec',
#  'p3L0HadronDecision_TIS',
#  'p3L0HadronDecision_TOS',
#  'p3L0HadronNoSPDDecision_Dec',
#  'p3L0HadronNoSPDDecision_TIS',
#  'p3L0HadronNoSPDDecision_TOS',
#  'p3L0MuonDecision_Dec',
#  'p3L0MuonDecision_TIS',
#  'p3L0MuonDecision_TOS',
#  'p3L0MuonNoSPDDecision_Dec',
#  'p3L0MuonNoSPDDecision_TIS',
#  'p3L0MuonNoSPDDecision_TOS',
#  'p3L0PhotonDecision_Dec',
#  'p3L0PhotonDecision_TIS',
#  'p3L0PhotonDecision_TOS',
#  'p3L0PhotonNoSPDDecision_Dec',
#  'p3L0PhotonNoSPDDecision_TIS',
#  'p3L0PhotonNoSPDDecision_TOS',
#  'p3StrippingGlobal_Dec',
#  'p3StrippingGlobal_TIS',
#  'p3StrippingGlobal_TOS',
#  'p3_Aerogel_Phi',
#  'p3_Aerogel_Rho',
#  'p3_Aerogel_X',
#  'p3_Aerogel_Y',
#  'p3_Aerogel_Z',
#  'p3_BPVIPCHI2',
#  'p3_BPVTRGPOINTING',
#  'p3_BPVVD',
#  'p3_DOCA',
#  'p3_DOCA12',
#  'p3_DOCA13',
#  'p3_DOCA23',
#  'p3_ID',
#  'p3_IPCHI2_ORIVX',
#  'p3_IPCHI2_OWNPV',
#  'p3_IPCHI2_TOPPV',
#  'p3_IP_ORIVX',
#  'p3_IP_OWNPV',
#  'p3_IP_TOPPV',
#  'p3_LOKI_ETA',
#  'p3_LOKI_MM',
#  'p3_LOKI_PHI',
#  'p3_M',
#  'p3_MC_GD_GD_MOTHER_ID',
#  'p3_MC_GD_GD_MOTHER_KEY',
#  'p3_MC_GD_MOTHER_ID',
#  'p3_MC_GD_MOTHER_KEY',
#  'p3_MC_MOTHER_ID',
#  'p3_MC_MOTHER_KEY',
#  'p3_MINIP',
#  'p3_MINIPCHI2',
#  'p3_MINIPCHI2NEXTBEST',
#  'p3_MINIPNEXTBEST',
#  'p3_MINVDDV',
#  'p3_ORIVX_CHI2',
#  'p3_ORIVX_COV_',
#  'p3_ORIVX_NDOF',
#  'p3_ORIVX_X',
#  'p3_ORIVX_XERR',
#  'p3_ORIVX_Y',
#  'p3_ORIVX_YERR',
#  'p3_ORIVX_Z',
#  'p3_ORIVX_ZERR',
#  'p3_OSCIL',
#  'p3_OWNPV_CHI2',
#  'p3_OWNPV_COV_',
#  'p3_OWNPV_NDOF',
#  'p3_OWNPV_X',
#  'p3_OWNPV_XERR',
#  'p3_OWNPV_Y',
#  'p3_OWNPV_YERR',
#  'p3_OWNPV_Z',
#  'p3_OWNPV_ZERR',
#  'p3_P',
#  'p3_PE',
#  'p3_PIDK',
#  'p3_PIDe',
#  'p3_PIDmu',
#  'p3_PIDp',
#  'p3_PT',
#  'p3_PX',
#  'p3_PY',
#  'p3_PZ',
#  'p3_ProbNNe',
#  'p3_ProbNNghost',
#  'p3_ProbNNk',
#  'p3_ProbNNmu',
#  'p3_ProbNNp',
#  'p3_ProbNNpi',
#  'p3_RICH1GasUsed',
#  'p3_RICH2GasUsed',
#  'p3_RICHAerogelUsed',
#  'p3_RICHBestID',
#  'p3_RICHDLLK',
#  'p3_RICHDLLbt',
#  'p3_RICHDLLe',
#  'p3_RICHDLLmu',
#  'p3_RICHDLLp',
#  'p3_RICHDLLpi',
#  'p3_RICHThreshold',
#  'p3_RICHThresholdEl',
#  'p3_RICHThresholdKa',
#  'p3_RICHThresholdMu',
#  'p3_RICHThresholdPi',
#  'p3_RICHThresholdPr',
#  'p3_Rich1Gas_Phi',
#  'p3_Rich1Gas_Rho',
#  'p3_Rich1Gas_X',
#  'p3_Rich1Gas_Y',
#  'p3_Rich1Gas_Z',
#  'p3_Rich2Gas_Phi',
#  'p3_Rich2Gas_Rho',
#  'p3_Rich2Gas_X',
#  'p3_Rich2Gas_Y',
#  'p3_Rich2Gas_Z',
#  'p3_TOPPV_CHI2',
#  'p3_TOPPV_COV_',
#  'p3_TOPPV_NDOF',
#  'p3_TOPPV_X',
#  'p3_TOPPV_XERR',
#  'p3_TOPPV_Y',
#  'p3_TOPPV_YERR',
#  'p3_TOPPV_Z',
#  'p3_TOPPV_ZERR',
#  'p3_TRACK_CHI2',
#  'p3_TRACK_CHI2NDOF',
#  'p3_TRACK_CloneDist',
#  'p3_TRACK_Eta',
#  'p3_TRACK_GhostProb',
#  'p3_TRACK_Key',
#  'p3_TRACK_MatchCHI2',
#  'p3_TRACK_NDOF',
#  'p3_TRACK_PCHI2',
#  'p3_TRACK_Phi',
#  'p3_TRACK_TCHI2NDOF',
#  'p3_TRACK_Type',
#  'p3_TRACK_VeloCHI2NDOF',
#  'p3_TRUEENDVERTEX_X',
#  'p3_TRUEENDVERTEX_Y',
#  'p3_TRUEENDVERTEX_Z',
#  'p3_TRUEID',
#  'p3_TRUEISSTABLE',
#  'p3_TRUEORIGINVERTEX_X',
#  'p3_TRUEORIGINVERTEX_Y',
#  'p3_TRUEORIGINVERTEX_Z',
#  'p3_TRUEPT',
#  'p3_TRUEP_E',
#  'p3_TRUEP_X',
#  'p3_TRUEP_Y',
#  'p3_TRUEP_Z',
#  'p3_TRUETAU',
#  'p3_VELO_UTID',
#  'p3_VFASPFVCHI2',
#  'p3_dcaSVPV_CHI2',
#  'p3_hasCalo',
#  'p3_hasMuon',
#  'p3_hasRich',
#  'p3_isMuon',
#  'p3_vchi2',
#  'runNumber',
#  'totCandidates']

# %% [markdown]
# <!---
# ubdt_args = {'uniform_variables': uniform_variables,
#              'n_estimators': n_estimators,
#              'base_estimator': base_tree,
#              'train_variables': train_variables}
#
# classifiers['uBDT0.0'] = uboost.uBoostBDT(smoothing=0.0, **ubdt_args )
#
# classifiers['uBDT0.1'] = uboost.uBoostBDT(smoothing=0.1, **ubdt_args )
#
# classifiers['uBDT1.0'] = uboost.uBoostBDT(smoothing=1.0, **ubdt_args )
#
# -->
